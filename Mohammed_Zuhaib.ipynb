# %% [markdown]
# ## Lending Club Case Study
#
# ### Business Understanding
#
# #### You work for a consumer finance company which specialises in lending various types of loans to urban customers. When the company receives a loan application, the company has to make a decision for loan approval based on the applicant’s profile. Two types of risks are associated with the bank’s decision. If the applicant is likely to repay the loan, then not approving the loan results in a loss of business to the company. If the applicant is not likely to repay the loan, i.e. he/she is likely to default, then approving the loan may lead to a financial loss for the company
#
# ### When a person applies for a loan, there are two types of decisions that could be taken by the company:
# #### Loan accepted: If the company approves the loan, there are 3 possible scenarios described below:
# #### Fully paid: Applicant has fully paid the loan (the principal and the interest rate)
# #### Current: Applicant is in the process of paying the instalments, i.e. the tenure of the loan is not yet completed. These candidates are not labelled as 'defaulted'.
# #### Charged-off: Applicant has not paid the instalments in due time for a long period of time, i.e. he/she has defaulted on the loan
# #### Loan rejected: The company had rejected the loan (because the candidate does not meet their requirements
#
# ### AIm: To identify how various factors affect the defaulting of a customer loan.

# %% [markdown]
# #### importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### code to ignore the warning messages

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Reading the data from the data frame

# %%
loan_data = pd.read_csv('loan.csv')
loan_data.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                NaN            NaN               NaN                  0.0
# 1                NaN            NaN               NaN                  0.0
# 2                NaN            NaN               NaN                  0.0
# 3                NaN            NaN               NaN                  0.0
# 4                NaN            NaN               NaN                  0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0       0.0             NaN               NaN            NaN
# 1       0.0             NaN               NaN            NaN
# 2       0.0             NaN               NaN            NaN
# 3       0.0             NaN               NaN            NaN
# 4       0.0             NaN               NaN            NaN
#
#   total_il_high_credit_limit
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 111 columns]

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %% [markdown]
# #### The number of columns are too large and we might not need all of them for our analysis, so we can drop the ones we don't need.

# %% [markdown]
# #### we will only consider the columns we need for our analysis. Our target variable is loan_status.

# %% [markdown]
# #### First let us drop all the columns having only NULL values which are of no use to us

# %%
df=loan_data.dropna(axis=1,how='all')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 57 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          39717 non-null  int64
#  1   member_id                   39717 non-null  int64
#  2   loan_amnt                   39717 non-null  int64
#  3   funded_amnt                 39717 non-null  int64
#  4   funded_amnt_inv             39717 non-null  float64
#  5   term                        39717 non-null  object
#  6   int_rate                    39717 non-null  object
#  7   installment                 39717 non-null  float64
#  8   grade                       39717 non-null  object
#  9   sub_grade                   39717 non-null  object
#  10  emp_title                   37258 non-null  object
#  11  emp_length                  38642 non-null  object
#  12  home_ownership              39717 non-null  object
#  13  annual_inc                  39717 non-null  float64
#  14  verification_status         39717 non-null  object
#  15  issue_d                     39717 non-null  object
#  16  loan_status                 39717 non-null  object
#  17  pymnt_plan                  39717 non-null  object
#  18  url                         39717 non-null  object
#  19  desc                        26777 non-null  object
#  20  purpose                     39717 non-null  object
#  21  title                       39706 non-null  object
#  22  zip_code                    39717 non-null  object
#  23  addr_state                  39717 non-null  object
#  24  dti                         39717 non-null  float64
#  25  delinq_2yrs                 39717 non-null  int64
#  26  earliest_cr_line            39717 non-null  object
#  27  inq_last_6mths              39717 non-null  int64
#  28  mths_since_last_delinq      14035 non-null  float64
#  29  mths_since_last_record      2786 non-null   float64
#  30  open_acc                    39717 non-null  int64
#  31  pub_rec                     39717 non-null  int64
#  32  revol_bal                   39717 non-null  int64
#  33  revol_util                  39667 non-null  object
#  34  total_acc                   39717 non-null  int64
#  35  initial_list_status         39717 non-null  object
#  36  out_prncp                   39717 non-null  float64
#  37  out_prncp_inv               39717 non-null  float64
#  38  total_pymnt                 39717 non-null  float64
#  39  total_pymnt_inv             39717 non-null  float64
#  40  total_rec_prncp             39717 non-null  float64
#  41  total_rec_int               39717 non-null  float64
#  42  total_rec_late_fee          39717 non-null  float64
#  43  recoveries                  39717 non-null  float64
#  44  collection_recovery_fee     39717 non-null  float64
#  45  last_pymnt_d                39646 non-null  object
#  46  last_pymnt_amnt             39717 non-null  float64
#  47  next_pymnt_d                1140 non-null   object
#  48  last_credit_pull_d          39715 non-null  object
#  49  collections_12_mths_ex_med  39661 non-null  float64
#  50  policy_code                 39717 non-null  int64
#  51  application_type            39717 non-null  object
#  52  acc_now_delinq              39717 non-null  int64
#  53  chargeoff_within_12_mths    39661 non-null  float64
#  54  delinq_amnt                 39717 non-null  int64
#  55  pub_rec_bankruptcies        39020 non-null  float64
#  56  tax_liens                   39678 non-null  float64
# dtypes: float64(20), int64(13), object(24)
# memory usage: 17.3+ MB

# %% [markdown]
# #### We can now pick the columns needed for analysis

# %%
loan = loan_data.loc[:,['id','loan_amnt','member_id','term','int_rate','installment','home_ownership','annual_inc','verification_status',
                        'issue_d','loan_status','pymnt_plan','addr_state','delinq_2yrs','mths_since_last_delinq',
                        'total_rec_late_fee','application_type','total_pymnt','last_pymnt_amnt','delinq_amnt','tax_liens','grade','sub_grade']]

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      39717 non-null  int64
#  1   loan_amnt               39717 non-null  int64
#  2   member_id               39717 non-null  int64
#  3   term                    39717 non-null  object
#  4   int_rate                39717 non-null  object
#  5   installment             39717 non-null  float64
#  6   home_ownership          39717 non-null  object
#  7   annual_inc              39717 non-null  float64
#  8   verification_status     39717 non-null  object
#  9   issue_d                 39717 non-null  object
#  10  loan_status             39717 non-null  object
#  11  pymnt_plan              39717 non-null  object
#  12  addr_state              39717 non-null  object
#  13  delinq_2yrs             39717 non-null  int64
#  14  mths_since_last_delinq  14035 non-null  float64
#  15  total_rec_late_fee      39717 non-null  float64
#  16  application_type        39717 non-null  object
#  17  total_pymnt             39717 non-null  float64
#  18  last_pymnt_amnt         39717 non-null  float64
#  19  delinq_amnt             39717 non-null  int64
#  20  tax_liens               39678 non-null  float64
#  21  grade                   39717 non-null  object
#  22  sub_grade               39717 non-null  object
# dtypes: float64(7), int64(5), object(11)
# memory usage: 7.0+ MB

# %% [markdown]
# #### we can drop mnths_since_last_delinq as well since more than half of it's values are NULL

# %%
loan = loan.drop(columns=['mths_since_last_delinq'])

# %% [markdown]
# ### Features
# * **id**  -                    A unique assigned ID for the loan listing.
# * **loan_amnt** -              The listed amount of the loan applied for by the borrower.
# * **member_id** -              A unique LC assigned Id for the borrower member.
# * **term** -                   The number of payments on the loan. Values are in months and can be either 36 or 60.
# * **int_rate** -               Interest Rate on the loan
# * **installment** -            The monthly payment owed by the borrower
# * **home_ownership** -         The home ownership status provided by the borrower during registration.
# * **annual_inc** -             The self-reported annual income provided by the borrower during registration.
# * **verification_status** -    Indicates if income was verified by LC, not verified
# * **issue_d** -                The month which the loan was funded
# * **loan_status** -            Current status of the loan
# * **pymnt_plan** -             Indicates if a payment plan has been put in place for the loan
# * **addr_state** -             The state provided by the borrower in the loan application
# * **delinq_2yrs** -            The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years
# * **total_rec_late_fee** -     Late fees received to date
# * **application_type** -       Indicates whether the loan is an individual application or a joint application
# * **total_pymnt** -            Payments received to date for total amount funded
# * **last_pymnt_amnt** -         Last total payment amount received
# * **delinq_amnt** -            The past-due amount owed for the accounts on which the borrower is now delinquent.
# * **tax_liens** -              Number of tax liens

# %%
loan.shape
# Out:
# (39717, 22)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   39717 non-null  int64
#  1   loan_amnt            39717 non-null  int64
#  2   member_id            39717 non-null  int64
#  3   term                 39717 non-null  object
#  4   int_rate             39717 non-null  object
#  5   installment          39717 non-null  float64
#  6   home_ownership       39717 non-null  object
#  7   annual_inc           39717 non-null  float64
#  8   verification_status  39717 non-null  object
#  9   issue_d              39717 non-null  object
#  10  loan_status          39717 non-null  object
#  11  pymnt_plan           39717 non-null  object
#  12  addr_state           39717 non-null  object
#  13  delinq_2yrs          39717 non-null  int64
#  14  total_rec_late_fee   39717 non-null  float64
#  15  application_type     39717 non-null  object
#  16  total_pymnt          39717 non-null  float64
#  17  last_pymnt_amnt      39717 non-null  float64
#  18  delinq_amnt          39717 non-null  int64
#  19  tax_liens            39678 non-null  float64
#  20  grade                39717 non-null  object
#  21  sub_grade            39717 non-null  object
# dtypes: float64(6), int64(5), object(11)
# memory usage: 6.7+ MB

# %% [markdown]
# #### tax_liens column has some NULL values, let us check it's distribution to see what can be done

# %%
loan.tax_liens.describe()
# Out:
# count    39678.0
# mean         0.0
# std          0.0
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          0.0
# Name: tax_liens, dtype: float64

# %%
loan.tax_liens.value_counts()
# Out:
# 0.0    39678
# Name: tax_liens, dtype: int64

# %% [markdown]
# #### As we can see that all the values are 0, we can drop this column for our anlysis

# %%
loan = loan.drop(columns=['tax_liens'])

# %%
loan.head()
# Out:
#         id  loan_amnt  member_id        term int_rate  installment  \
# 0  1077501       5000    1296599   36 months   10.65%       162.87
# 1  1077430       2500    1314167   60 months   15.27%        59.83
# 2  1077175       2400    1313524   36 months   15.96%        84.33
# 3  1076863      10000    1277178   36 months   13.49%       339.31
# 4  1075358       3000    1311748   60 months   12.69%        67.79
#
#   home_ownership  annual_inc verification_status issue_d  ... pymnt_plan  \
# 0           RENT     24000.0            Verified  Dec-11  ...          n
# 1           RENT     30000.0     Source Verified  Dec-11  ...          n
# 2           RENT     12252.0        Not Verified  Dec-11  ...          n
# 3           RENT     49200.0     Source Verified  Dec-11  ...          n
# 4           RENT     80000.0     Source Verified  Dec-11  ...          n
#
#   addr_state delinq_2yrs  total_rec_late_fee  application_type   total_pymnt  \
# 0         AZ           0                0.00        INDIVIDUAL   5863.155187
# 1         GA           0                0.00        INDIVIDUAL   1008.710000
# 2         IL           0                0.00        INDIVIDUAL   3005.666844
# 3         CA           0               16.97        INDIVIDUAL  12231.890000
# 4         OR           0                0.00        INDIVIDUAL   3513.330000
#
#    last_pymnt_amnt  delinq_amnt  grade sub_grade
# 0           171.62            0      B        B2
# 1           119.66            0      C        C4
# 2           649.91            0      C        C5
# 3           357.48            0      C        C1
# 4            67.79            0      B        B5
#
# [5 rows x 21 columns]

# %%
loan.delinq_amnt.value_counts()
# Out:
# 0    39717
# Name: delinq_amnt, dtype: int64

# %% [markdown]
# #### Since all the rows are zero in delinq_amnt we can drop this column

# %%
loan = loan.drop(columns=['delinq_amnt'])

# %% [markdown]
# #### loan.term should be an int but it is in the form of an object, similarly loan.int_rate should be converted to float

# %%
loan.term = loan.term.apply(lambda x: int(x.strip('months')))
loan.term.dtype
# Out:
# dtype('int64')

# %%
loan.int_rate = loan.int_rate.apply(lambda x: float(x.strip('%')))
loan.int_rate.dtype
# Out:
# dtype('float64')

# %%
loan.head()
# Out:
#         id  loan_amnt  member_id  term  int_rate  installment home_ownership  \
# 0  1077501       5000    1296599    36     10.65       162.87           RENT
# 1  1077430       2500    1314167    60     15.27        59.83           RENT
# 2  1077175       2400    1313524    36     15.96        84.33           RENT
# 3  1076863      10000    1277178    36     13.49       339.31           RENT
# 4  1075358       3000    1311748    60     12.69        67.79           RENT
#
#    annual_inc verification_status issue_d  loan_status pymnt_plan addr_state  \
# 0     24000.0            Verified  Dec-11   Fully Paid          n         AZ
# 1     30000.0     Source Verified  Dec-11  Charged Off          n         GA
# 2     12252.0        Not Verified  Dec-11   Fully Paid          n         IL
# 3     49200.0     Source Verified  Dec-11   Fully Paid          n         CA
# 4     80000.0     Source Verified  Dec-11      Current          n         OR
#
#    delinq_2yrs  total_rec_late_fee application_type   total_pymnt  \
# 0            0                0.00       INDIVIDUAL   5863.155187
# 1            0                0.00       INDIVIDUAL   1008.710000
# 2            0                0.00       INDIVIDUAL   3005.666844
# 3            0               16.97       INDIVIDUAL  12231.890000
# 4            0                0.00       INDIVIDUAL   3513.330000
#
#    last_pymnt_amnt grade sub_grade
# 0           171.62     B        B2
# 1           119.66     C        C4
# 2           649.91     C        C5
# 3           357.48     C        C1
# 4            67.79     B        B5

# %% [markdown]
# #### issue_d should be split in month and year to make analysis easier, create a new column by extracting month from issue_d

# %%
# Importing datetime Module to extract month from date
from datetime import datetime

def get_month(x):
    dt = datetime. strptime(x,'%b-%y')
    return dt.month
    
loan['issue_d_month'] = loan.issue_d.apply(get_month)

# %%
loan['issue_d_month']
# Out:
# 0        12
# 1        12
# 2        12
# 3        12
# 4        12
#          ..
# 39712     7
# 39713     7
# 39714     7
# 39715     7
# 39716     6
# Name: issue_d_month, Length: 39717, dtype: int64

# %%
loan.pymnt_plan.value_counts()
# Out:
# n    39717
# Name: pymnt_plan, dtype: int64

# %% [markdown]
# #### since all values are same in this column we can drop this column as well

# %%
loan = loan.drop(columns=['pymnt_plan'])

# %%
loan.head()
# Out:
#         id  loan_amnt  member_id  term  int_rate  installment home_ownership  \
# 0  1077501       5000    1296599    36     10.65       162.87           RENT
# 1  1077430       2500    1314167    60     15.27        59.83           RENT
# 2  1077175       2400    1313524    36     15.96        84.33           RENT
# 3  1076863      10000    1277178    36     13.49       339.31           RENT
# 4  1075358       3000    1311748    60     12.69        67.79           RENT
#
#    annual_inc verification_status issue_d  loan_status addr_state  \
# 0     24000.0            Verified  Dec-11   Fully Paid         AZ
# 1     30000.0     Source Verified  Dec-11  Charged Off         GA
# 2     12252.0        Not Verified  Dec-11   Fully Paid         IL
# 3     49200.0     Source Verified  Dec-11   Fully Paid         CA
# 4     80000.0     Source Verified  Dec-11      Current         OR
#
#    delinq_2yrs  total_rec_late_fee application_type   total_pymnt  \
# 0            0                0.00       INDIVIDUAL   5863.155187
# 1            0                0.00       INDIVIDUAL   1008.710000
# 2            0                0.00       INDIVIDUAL   3005.666844
# 3            0               16.97       INDIVIDUAL  12231.890000
# 4            0                0.00       INDIVIDUAL   3513.330000
#
#    last_pymnt_amnt grade sub_grade  issue_d_month
# 0           171.62     B        B2             12
# 1           119.66     C        C4             12
# 2           649.91     C        C5             12
# 3           357.48     C        C1             12
# 4            67.79     B        B5             12

# %% [markdown]
# #### Since our Primary Analysis is for Defaulting Customers we can filter the data set appropriately by removing Current loan status records as we can't infer anything from them.

# %%
loan1 = loan[loan.loan_status == 'Charged Off']
loan1.shape
# Out:
# (5627, 20)

# %% [markdown]
# #### Detecting outliers in Numeric data types

# %%
loan1.loan_amnt.describe()
# Out:
# count     5627.000000
# mean     12104.385108
# std       8085.732038
# min        900.000000
# 25%       5600.000000
# 50%      10000.000000
# 75%      16500.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %%
plt.boxplot(loan1['loan_amnt'])
plt.title("Boxplot of Loan Amount")
plt.ylabel("Loan amount")
plt.show()

# %%
loan1[loan1.loan_amnt > 33000]
# Out:
#             id  loan_amnt  member_id  term  int_rate  installment  \
# 430    1029473      33425    1258841    60     13.49       475.63
# 496    1063393      35000    1295948    60     20.30       619.88
# 765    1053763      35000    1285365    60     20.89       576.27
# 836    1059319      35000    1291122    60     19.03       593.77
# 887    1058824      35000    1290419    60     20.89       944.71
# ...        ...        ...        ...   ...       ...          ...
# 19027   683184      35000     872476    60     16.02       851.51
# 19142   679239      35000     867705    60     16.77       865.52
# 19238   679046      35000     867473    60     16.40       858.59
# 19430   674982      35000     862684    60     21.22       951.21
# 19578   673070      35000     860334    60     17.51       879.47
#
#       home_ownership  annual_inc verification_status issue_d  loan_status  \
# 430         MORTGAGE     75000.0     Source Verified  Dec-11  Charged Off
# 496              OWN     85000.0            Verified  Dec-11  Charged Off
# 765         MORTGAGE     71316.0            Verified  Dec-11  Charged Off
# 836         MORTGAGE    235000.0            Verified  Dec-11  Charged Off
# 887             RENT     90000.0     Source Verified  Dec-11  Charged Off
# ...              ...         ...                 ...     ...          ...
# 19027       MORTGAGE     92000.0            Verified  Feb-11  Charged Off
# 19142       MORTGAGE    101000.0            Verified  Feb-11  Charged Off
# 19238            OWN     76000.0            Verified  Feb-11  Charged Off
# 19430       MORTGAGE     58000.0            Verified  Feb-11  Charged Off
# 19578       MORTGAGE    113000.0            Verified  Feb-11  Charged Off
#
#       addr_state  delinq_2yrs  total_rec_late_fee application_type  \
# 430           NY            0            0.000000       INDIVIDUAL
# 496           FL            0            0.000000       INDIVIDUAL
# 765           NC            1            0.000000       INDIVIDUAL
# 836           CA            0            0.000000       INDIVIDUAL
# 887           CA            0           94.480000       INDIVIDUAL
# ...          ...          ...                 ...              ...
# 19027         NV            0            0.000000       INDIVIDUAL
# 19142         MA            0            0.000000       INDIVIDUAL
# 19238         FL            0            0.000000       INDIVIDUAL
# 19430         NY            0           44.940951       INDIVIDUAL
# 19578         CO            1            0.000000       INDIVIDUAL
#
#        total_pymnt  last_pymnt_amnt grade sub_grade  issue_d_month
# 430       19893.95          1370.08     C        C1             12
# 496        3093.50           619.88     E        E5             12
# 765        1151.20           576.27     F        F1             12
# 836       19075.97            31.28     E        E2             12
# 887       43184.67           944.71     F        F1             12
# ...            ...              ...   ...       ...            ...
# 19027     13217.03          3000.00     D        D5              2
# 19142     28981.17            32.06     E        E2              2
# 19238     10297.35           200.33     E        E1              2
# 19430     14374.43           952.25     G        G4              2
# 19578      3511.24           879.47     E        E4              2
#
# [157 rows x 20 columns]

# %%
loan1 = loan1[loan1.loan_amnt <= 33000]
loan1.shape
# Out:
# (5470, 20)

# %%
loan1.int_rate.describe()
# Out:
# count    5470.000000
# mean       13.715982
# std         3.603932
# min         5.420000
# 25%        11.140000
# 50%        13.490000
# 75%        16.320000
# max        24.400000
# Name: int_rate, dtype: float64

# %%
plt.boxplot(loan1['int_rate'])
plt.title("Box Plot of Interest Rate")
plt.ylabel("Interest Rate")
plt.show()

# %%
loan1[loan1.int_rate > 23]
# Out:
#             id  loan_amnt  member_id  term  int_rate  installment  \
# 601    1058624      12375    1290219    60     23.13       349.79
# 2447   1036060      26300    1265925    60     23.13       743.38
# 2749    896003      30000    1116554    60     23.52       854.71
# 2801   1031468      14825    1261116    60     23.52       422.37
# 3094   1025574      30000    1254736    60     23.13       847.96
# 4214   1006364      23200    1232779    60     23.52       660.97
# 4314   1004462      18400    1230902    60     23.13       520.08
# 5820    977981      17625    1200792    60     23.91       506.12
# 5964    976164      21250    1198310    60     24.11       612.68
# 9854    842083      13650    1052700    60     23.59       389.45
# 10661   829308      10000    1038407    60     23.22       283.18
# 13492   774690      12000     976878    60     24.40       348.01
#
#       home_ownership  annual_inc verification_status issue_d  loan_status  \
# 601             RENT    40000.00        Not Verified  Dec-11  Charged Off
# 2447        MORTGAGE    65000.00     Source Verified  Dec-11  Charged Off
# 2749            RENT   110000.00            Verified  Dec-11  Charged Off
# 2801            RENT    45600.00     Source Verified  Nov-11  Charged Off
# 3094            RENT   102500.00            Verified  Nov-11  Charged Off
# 4214        MORTGAGE    85000.00            Verified  Nov-11  Charged Off
# 4314        MORTGAGE    75000.00            Verified  Nov-11  Charged Off
# 5820        MORTGAGE   400000.00            Verified  Oct-11  Charged Off
# 5964            RENT    80000.00            Verified  Oct-11  Charged Off
# 9854            RENT    40000.00        Not Verified  Aug-11  Charged Off
# 10661           RENT    33280.00            Verified  Jul-11  Charged Off
# 13492           RENT    35775.63        Not Verified  Jun-11  Charged Off
#
#       addr_state  delinq_2yrs  total_rec_late_fee application_type  \
# 601           FL            0            0.000000       INDIVIDUAL
# 2447          OH            0            0.000000       INDIVIDUAL
# 2749          DC            0           42.686994       INDIVIDUAL
# 2801          FL            0            0.000000       INDIVIDUAL
# 3094          CA            0            0.000000       INDIVIDUAL
# 4214          TX            0            0.000000       INDIVIDUAL
# 4314          FL            1            0.000000       INDIVIDUAL
# 5820          TX            0            0.000000       INDIVIDUAL
# 5964          NY            0           30.480934       INDIVIDUAL
# 9854          NJ            0            0.000000       INDIVIDUAL
# 10661         VA            0            0.000000       INDIVIDUAL
# 13492         NY            0            0.000000       INDIVIDUAL
#
#        total_pymnt  last_pymnt_amnt grade sub_grade  issue_d_month
# 601        8530.26            52.05     G        G2             12
# 2447      16354.36           743.38     G        G2             12
# 2749       7625.93           876.00     G        G3             12
# 2801       2183.83           844.74     G        G3             11
# 3094       7810.50           100.00     G        G2             11
# 4214      31471.29           200.00     G        G3             11
# 4314       9707.88            40.12     G        G2             11
# 5820      20896.16           506.12     G        G4             10
# 5964      10258.65           150.78     G        G5             10
# 9854      15463.37           389.45     G        G5              8
# 10661     10037.99           283.18     G        G4              7
# 13492      4777.71           696.02     G        G4              6

# %%
loan1 = loan1[loan1.int_rate <= 23]

# %%
plt.boxplot(loan1.total_pymnt)
plt.title("Boxplot of Total Payment")
plt.ylabel("total_pymnt")
plt.show()

# %%
loan1[loan1.total_pymnt > 33000]
# Out:
#             id  loan_amnt  member_id  term  int_rate  installment  \
# 2030   1041534      33000    1271765    36     18.64      1203.66
# 5643    981929      30000    1205316    60     22.06       829.60
# 5863    978431      25000    1201269    60     21.67       685.80
# 7632    878770      32000    1093592    36     15.23      1112.90
# 9694    812337      32350    1019488    60     21.74       888.70
# 15185   753084      32000     952719    60     18.39       819.40
# 15636   743946      30000     942334    60     16.89       696.08
# 17877   708969      30000     901520    60     17.51       753.83
# 18848   685965      25975     875698    60     15.28       621.77
# 26985   560150      25000     720996    60     13.61       576.67
#
#       home_ownership  annual_inc verification_status issue_d  loan_status  \
# 2030        MORTGAGE    115000.0     Source Verified  Dec-11  Charged Off
# 5643        MORTGAGE    160000.0            Verified  Oct-11  Charged Off
# 5863        MORTGAGE     66000.0     Source Verified  Oct-11  Charged Off
# 7632        MORTGAGE     60000.0            Verified  Sep-11  Charged Off
# 9694        MORTGAGE     91000.0            Verified  Aug-11  Charged Off
# 15185           RENT    182004.0     Source Verified  May-11  Charged Off
# 15636       MORTGAGE     99996.0            Verified  May-11  Charged Off
# 17877       MORTGAGE    100000.0            Verified  Mar-11  Charged Off
# 18848       MORTGAGE     40000.0            Verified  Mar-11  Charged Off
# 26985       MORTGAGE    124800.0            Verified  Aug-10  Charged Off
#
#       addr_state  delinq_2yrs  total_rec_late_fee application_type  \
# 2030          MD            1            0.000000       INDIVIDUAL
# 5643          CA            0           41.480000       INDIVIDUAL
# 5863          IL            0            0.000000       INDIVIDUAL
# 7632          VA            0            0.000000       INDIVIDUAL
# 9694          NJ            0            0.000000       INDIVIDUAL
# 15185         CA            0            0.000000       INDIVIDUAL
# 15636         PA            0            0.000000       INDIVIDUAL
# 17877         GA            0            0.000000       INDIVIDUAL
# 18848         TX            0            0.000000       INDIVIDUAL
# 26985         NY            0           28.796561       INDIVIDUAL
#
#        total_pymnt  last_pymnt_amnt grade sub_grade  issue_d_month
# 2030      36040.93          1203.66     E        E1             12
# 5643      37610.61           829.60     F        F4             10
# 5863      33876.24           685.80     F        F3             10
# 7632      37523.12            36.54     C        C5              9
# 9694      42134.53           888.70     F        F5              8
# 15185     33594.12           819.40     E        E2              5
# 15636     35389.04           696.08     D        D4              5
# 17877     34855.27            38.57     E        E4              3
# 18848     33600.94           621.77     D        D3              3
# 26985     34765.35           865.02     C        C2              8

# %%
loan1 = loan1[loan1.total_pymnt <= 33000]

# %%
loan1.shape
# Out:
# (5448, 20)

# %%
plt.boxplot(loan1.last_pymnt_amnt)
plt.title("Boxplot of Total Amount Paid Yet")
plt.ylabel("last_pymnt_amnt")
plt.show()

# %%
loan1[loan1.last_pymnt_amnt > 3000]
# Out:
#             id  loan_amnt  member_id  term  int_rate  installment  \
# 255    1066232      10000    1300594    36     12.42       334.16
# 570    1062478      28000    1294543    60     12.42       418.27
# 8311    865523      21500    1078839    36     16.89       765.36
# 9782    819977      25300    1028154    36     10.99       828.17
# 9963    840354       8450    1050722    60     11.49       185.80
# 10572   829797      21600    1038921    60     14.79       511.49
# 12737   788280      12225     991953    60     17.49       307.06
# 12951   789015       8000     992835    36      7.49       248.82
# 15480   726234      17000     921576    60     11.99       378.07
# 17823   708214      16000     900684    60      9.63       337.05
# 19349   677087       7000     865140    60     16.77       173.11
# 23228   616966      14600     791031    36     12.61       489.20
# 23304   611082      25000     783664    60     20.77       428.77
# 23660   610101      20000     782481    60     19.29       522.01
# 24246   602918      20000     773589    60      9.62       421.22
# 28862   531151      16000     686739    60     15.58       385.53
# 30441   506881      25000     653616    36     10.99       818.38
# 32790   477494      15000     605699    36     12.18       499.50
# 35765   430330       7750     510315    36     19.79       287.20
# 38965   289873      16400     289870    36     11.03       537.15
#
#       home_ownership  annual_inc verification_status issue_d  loan_status  \
# 255             RENT     39000.0     Source Verified  Dec-11  Charged Off
# 570         MORTGAGE     84996.0            Verified  Dec-11  Charged Off
# 8311            RENT     65000.0            Verified  Sep-11  Charged Off
# 9782            RENT     95000.0            Verified  Aug-11  Charged Off
# 9963            RENT     42000.0     Source Verified  Aug-11  Charged Off
# 10572       MORTGAGE     32160.0            Verified  Aug-11  Charged Off
# 12737       MORTGAGE    105000.0        Not Verified  Jun-11  Charged Off
# 12951       MORTGAGE     87000.0        Not Verified  Jun-11  Charged Off
# 15480       MORTGAGE     58000.0            Verified  May-11  Charged Off
# 17823           RENT     33924.0            Verified  Mar-11  Charged Off
# 19349           RENT     70000.0     Source Verified  Feb-11  Charged Off
# 23228            OWN     36000.0     Source Verified  Nov-10  Charged Off
# 23304       MORTGAGE    120000.0            Verified  Nov-10  Charged Off
# 23660           RENT     72396.0        Not Verified  Nov-10  Charged Off
# 24246            OWN     96000.0     Source Verified  Oct-10  Charged Off
# 28862       MORTGAGE     78000.0            Verified  Jun-10  Charged Off
# 30441       MORTGAGE    132000.0        Not Verified  May-10  Charged Off
# 32790            OWN     70000.0        Not Verified  Feb-10  Charged Off
# 35765       MORTGAGE     53000.0            Verified  Aug-09  Charged Off
# 38965           RENT     49920.0        Not Verified  Mar-08  Charged Off
#
#       addr_state  delinq_2yrs  total_rec_late_fee application_type  \
# 255           MO            0            0.000000       INDIVIDUAL
# 570           GA            0           20.890628       INDIVIDUAL
# 8311          CA            0           74.685349       INDIVIDUAL
# 9782          NY            0            0.000000       INDIVIDUAL
# 9963          NC            0            0.000000       INDIVIDUAL
# 10572         NC            0            0.000000       INDIVIDUAL
# 12737         FL            0           15.347575       INDIVIDUAL
# 12951         CA            0            0.000000       INDIVIDUAL
# 15480         CA            0            0.000000       INDIVIDUAL
# 17823         PA            0            0.000000       INDIVIDUAL
# 19349         CA            0           14.997480       INDIVIDUAL
# 23228         IL            0            0.000000       INDIVIDUAL
# 23304         VA            1            0.000000       INDIVIDUAL
# 23660         HI            2           26.059269       INDIVIDUAL
# 24246         NY            1            0.000000       INDIVIDUAL
# 28862         MN            0            0.000000       INDIVIDUAL
# 30441         MI            0            0.000000       INDIVIDUAL
# 32790         NJ            0           24.976774       INDIVIDUAL
# 35765         FL            0            0.000000       INDIVIDUAL
# 38965         CA            0            0.000000       INDIVIDUAL
#
#        total_pymnt  last_pymnt_amnt grade sub_grade  issue_d_month
# 255       11604.88          4378.02     B        B4             12
# 570       14647.04         10000.00     B        B4             12
# 8311      18691.79          4152.00     D        D4              9
# 9782      25242.42          3711.12     B        B3              8
# 9963       7608.77          6309.65     B        B4              8
# 10572     18858.89         11328.71     C        C4              8
# 12737      6931.98          5000.00     D        D5              6
# 12951      5308.78          3584.00     A        A4              6
# 15480      9311.51          8184.05     B        B5              5
# 17823     15951.85          3618.05     B        B1              3
# 19349      5865.34          5005.84     E        E2              2
# 23228     17835.20          3500.00     C        C2             11
# 23304     14482.94          8480.98     G        G4             11
# 23660     24816.96          6000.00     F        F5             11
# 24246     14984.67          4841.69     B        B3             10
# 28862     19634.58         10021.06     D        D3              6
# 30441     20404.77         12818.38     B        B4              5
# 32790     14383.43         12390.99     B        B4              2
# 35765      8843.42          3300.00     G        G4              8
# 38965     17605.28          5809.23     C        C1              3

# %%
loan1 = loan1[loan1.last_pymnt_amnt <= 3000]

# %%
loan1.shape
# Out:
# (5428, 20)

# %%
plt.boxplot(loan1.installment)
plt.title("Boxplot of Installemts")
plt.ylabel("installments")
plt.show()

# %%
loan1[loan1.installment > 900]
# Out:
#             id  loan_amnt  member_id  term  int_rate  installment  \
# 2373   1037026      28000    1266711    36     16.77       995.08
# 3309   1020845      30750    1249631    36     18.25      1115.55
# 4033    994506      30000    1219134    36      7.51       933.33
# 4389   1003549      30000    1230136    36     10.65       977.20
# 4549   1000967      30000    1226719    36     17.27      1073.62
# 6176    971860      30000    1193617    36      6.62       921.11
# 6963    889797      30000    1106361    36     12.69      1006.35
# 7080    886292      25500    1102106    36     17.27       912.58
# 8551    864057      28000    1077267    36     12.99       943.30
# 8699    862084      26400    1075011    36     16.49       934.55
# 11727   809149      28000    1015938    36     11.99       929.87
# 11898   806771      30000    1013140    36     16.49      1061.99
# 12186   801934      29100    1007553    36     12.99       980.36
# 13710   777541      30000     980049    36     18.39      1090.46
# 14708   761798      30000     962276    36     15.62      1049.10
# 14965   755983      30000     955882    36     16.49      1061.99
# 23596   611270      25000     783892    36     17.80       901.31
# 25488   584264      25000     750735    36     21.64       950.12
# 27446   553306      25000     712920    36     19.04       916.91
# 30019   515070      25000     665822    36     19.41       921.60
# 30785   500302      25000     642500    36     19.79       926.37
# 31843   490180      25000     625782    36     20.16       931.09
# 32316   483973      25000     615993    36     18.30       907.60
# 32842   476988      25000     604531    36     18.09       904.88
# 32950   475731      25000     602343    36     18.43       909.25
# 34319   453516      25000     560743    36     19.13       918.02
# 34793   440545      25000     533658    36     18.09       904.88
# 36091   422412      25000     496900    36     17.90       902.50
#
#       home_ownership  annual_inc verification_status issue_d  loan_status  \
# 2373             OWN     76000.0            Verified  Nov-11  Charged Off
# 3309            RENT     80000.0            Verified  Nov-11  Charged Off
# 4033             OWN    125000.0            Verified  Nov-11  Charged Off
# 4389            RENT     97000.0            Verified  Oct-11  Charged Off
# 4549        MORTGAGE     75000.0            Verified  Oct-11  Charged Off
# 6176        MORTGAGE     61500.0            Verified  Oct-11  Charged Off
# 6963            RENT     84000.0            Verified  Sep-11  Charged Off
# 7080        MORTGAGE     75000.0     Source Verified  Oct-11  Charged Off
# 8551        MORTGAGE    160000.0     Source Verified  Sep-11  Charged Off
# 8699        MORTGAGE     68000.0            Verified  Aug-11  Charged Off
# 11727           RENT    120000.0     Source Verified  Jul-11  Charged Off
# 11898       MORTGAGE    120000.0            Verified  Jul-11  Charged Off
# 12186       MORTGAGE     52000.0            Verified  Jul-11  Charged Off
# 13710       MORTGAGE    116000.0            Verified  Jun-11  Charged Off
# 14708       MORTGAGE    125000.0            Verified  Jun-11  Charged Off
# 14965       MORTGAGE     72357.0            Verified  May-11  Charged Off
# 23596       MORTGAGE     80000.0            Verified  Nov-10  Charged Off
# 25488           RENT    203000.0            Verified  Sep-10  Charged Off
# 27446       MORTGAGE     61365.0     Source Verified  Jul-10  Charged Off
# 30019       MORTGAGE     75000.0            Verified  May-10  Charged Off
# 30785       MORTGAGE    123000.0            Verified  Apr-10  Charged Off
# 31843       MORTGAGE     60000.0        Not Verified  Mar-10  Charged Off
# 32316           RENT    235000.0        Not Verified  Feb-10  Charged Off
# 32842       MORTGAGE    100000.0        Not Verified  Jan-10  Charged Off
# 32950           RENT     54000.0        Not Verified  Jan-10  Charged Off
# 34319       MORTGAGE    148000.0            Verified  Nov-09  Charged Off
# 34793       MORTGAGE     70000.0            Verified  Oct-09  Charged Off
# 36091          OTHER     85000.0            Verified  Jul-09  Charged Off
#
#       addr_state  delinq_2yrs  total_rec_late_fee application_type  \
# 2373          OH            0            0.000000       INDIVIDUAL
# 3309          CA            0            0.000000       INDIVIDUAL
# 4033          NY            0            0.000000       INDIVIDUAL
# 4389          MI            0           14.997547       INDIVIDUAL
# 4549          TX            0            0.000000       INDIVIDUAL
# 6176          FL            0            0.000000       INDIVIDUAL
# 6963          NY            0            0.000000       INDIVIDUAL
# 7080          WA            0            0.000000       INDIVIDUAL
# 8551          TX            0            0.000000       INDIVIDUAL
# 8699          FL            0            0.000000       INDIVIDUAL
# 11727         CA            0            0.000000       INDIVIDUAL
# 11898         TX            1            0.000000       INDIVIDUAL
# 12186         FL            0            0.000000       INDIVIDUAL
# 13710         CA            0            0.000000       INDIVIDUAL
# 14708         CA            0           50.332465       INDIVIDUAL
# 14965         TX            2            0.000000       INDIVIDUAL
# 23596         FL            0            0.000000       INDIVIDUAL
# 25488         MA            0            0.000000       INDIVIDUAL
# 27446         TX            0            0.000000       INDIVIDUAL
# 30019         CA            0            0.000000       INDIVIDUAL
# 30785         MI            0            0.000000       INDIVIDUAL
# 31843         TX            0           61.456737       INDIVIDUAL
# 32316         NY            1           45.371707       INDIVIDUAL
# 32842         AZ            0           45.114720       INDIVIDUAL
# 32950         CO            0            0.000000       INDIVIDUAL
# 34319         AZ            1            0.000000       INDIVIDUAL
# 34793         PA            0            0.000000       INDIVIDUAL
# 36091         CA            0            0.000000       INDIVIDUAL
#
#        total_pymnt  last_pymnt_amnt grade sub_grade  issue_d_month
# 2373      32751.27           400.00     D        D2             11
# 3309       8716.70          1115.55     D        D5             11
# 4033       5574.67           933.33     A        A3             11
# 4389      14800.55          1957.08     B        B2             10
# 4549      16102.20          1073.62     D        D3             10
# 6176      19230.57            26.60     A        A2             10
# 6963      30240.82           133.49     B        B5              9
# 7080      12884.24           912.58     D        D3             10
# 8551      20751.38           943.30     C        C1              9
# 8699      14612.11            64.98     D        D3              8
# 11727     22942.54           929.87     B        B5              7
# 11898     20176.39            29.64     D        D3              7
# 12186     14821.09           980.36     C        C1              7
# 13710     29609.57            81.23     E        E2              6
# 14708     32348.50          2106.85     D        D1              6
# 14965     17032.97            35.09     D        D3              5
# 23596     10755.71           901.31     F        F1             11
# 25488     14687.91           950.12     G        G5              9
# 27446      8825.53           525.00     F        F3              7
# 30019     12900.23           929.79     F        F4              5
# 30785     27069.89            42.20     F        F5              4
# 31843     18924.18           801.27     G        G1              3
# 32316     14112.72          2000.12     F        F1              2
# 32842     23110.95           120.05     F        F1              1
# 32950     18320.25           275.00     F        F2              1
# 34319     18261.14           918.02     F        F4             11
# 34793     14477.45           904.88     F        F1             10
# 36091     18049.62           902.50     F        F3              7

# %%
loan1 = loan1[loan1.installment <= 900]

# %%
loan1.head()
# Out:
#          id  loan_amnt  member_id  term  int_rate  installment home_ownership  \
# 1   1077430       2500    1314167    60     15.27        59.83           RENT
# 8   1071795       5600    1306957    60     21.28       152.39            OWN
# 9   1071570       5375    1306721    60     12.69       121.45           RENT
# 12  1064687       9000    1298717    36     13.49       305.38           RENT
# 14  1069057      10000    1303503    36     10.65       325.74           RENT
#
#     annual_inc verification_status issue_d  loan_status addr_state  \
# 1      30000.0     Source Verified  Dec-11  Charged Off         GA
# 8      40000.0     Source Verified  Dec-11  Charged Off         CA
# 9      15000.0            Verified  Dec-11  Charged Off         TX
# 12     30000.0     Source Verified  Dec-11  Charged Off         VA
# 14    100000.0     Source Verified  Dec-11  Charged Off         CA
#
#     delinq_2yrs  total_rec_late_fee application_type  total_pymnt  \
# 1             0                 0.0       INDIVIDUAL      1008.71
# 8             0                 0.0       INDIVIDUAL       646.02
# 9             0                 0.0       INDIVIDUAL      1476.19
# 12            0                 0.0       INDIVIDUAL      2270.70
# 14            0                 0.0       INDIVIDUAL      7471.99
#
#     last_pymnt_amnt grade sub_grade  issue_d_month
# 1            119.66     C        C4             12
# 8            152.39     F        F2             12
# 9            121.45     B        B5             12
# 12           305.38     C        C1             12
# 14           325.74     B        B2             12

# %%
loan1.shape
# Out:
# (5400, 20)

# %% [markdown]
# ### Univariate Analysis

# %%
sns.distplot(loan1.loan_amnt)
plt.title("Distribution of Loan Amount for Defaulting Category", x=0.5, y=1.1)
plt.show()
sns.distplot(loan.loan_amnt)
plt.title("Distribution of Loan Amount for Entire Dataset")
plt.show()

# %% [markdown]
# #### From the above plots can conclude that loan is usually borrowed in 2.5k intervals by more number of people, spikes at 2.5k intervals say so.

# %%
sns.distplot(loan1.installment)
plt.title("Distribution of Installment for Charged Off Customers")
plt.show()
sns.distplot(loan.installment)
plt.title("Distribution of Installment for Entire Dataset")
plt.show()

# %% [markdown]
# #### Maximum number of people pay for installments per month of 200.

# %%
sns.distplot(loan1.last_pymnt_amnt)
plt.title("Distribution of last_pymnt_amnt")
plt.show()
loan1.last_pymnt_amnt.describe()
# Out:
# count    5400.000000
# mean      285.338102
# std       239.246394
# min         0.000000
# 25%       110.832500
# 50%       229.875000
# 75%       391.460000
# max      3000.000000
# Name: last_pymnt_amnt, dtype: float64

# %% [markdown]
# #### This indicates that most people who been charged off have paid balance amount between 0 - 1k.

# %%
sns.distplot(loan1.term)
plt.title("Distribution of term")
plt.show()

# %% [markdown]
# #### This shows that people whose term is 36 months are more likely to default than those who have term as 60 months. The difference is nearly 1.5 times.

# %%
sns.distplot(loan1.annual_inc)
plt.title("Distribution of Annual Income")
plt.show()

# %% [markdown]
# #### People who have Annual Income Less than 2 Lakhs are more likely to Default on a Loan

# %%
loan1.head()
# Out:
#          id  loan_amnt  member_id  term  int_rate  installment home_ownership  \
# 1   1077430       2500    1314167    60     15.27        59.83           RENT
# 8   1071795       5600    1306957    60     21.28       152.39            OWN
# 9   1071570       5375    1306721    60     12.69       121.45           RENT
# 12  1064687       9000    1298717    36     13.49       305.38           RENT
# 14  1069057      10000    1303503    36     10.65       325.74           RENT
#
#     annual_inc verification_status issue_d  loan_status addr_state  \
# 1      30000.0     Source Verified  Dec-11  Charged Off         GA
# 8      40000.0     Source Verified  Dec-11  Charged Off         CA
# 9      15000.0            Verified  Dec-11  Charged Off         TX
# 12     30000.0     Source Verified  Dec-11  Charged Off         VA
# 14    100000.0     Source Verified  Dec-11  Charged Off         CA
#
#     delinq_2yrs  total_rec_late_fee application_type  total_pymnt  \
# 1             0                 0.0       INDIVIDUAL      1008.71
# 8             0                 0.0       INDIVIDUAL       646.02
# 9             0                 0.0       INDIVIDUAL      1476.19
# 12            0                 0.0       INDIVIDUAL      2270.70
# 14            0                 0.0       INDIVIDUAL      7471.99
#
#     last_pymnt_amnt grade sub_grade  issue_d_month
# 1            119.66     C        C4             12
# 8            152.39     F        F2             12
# 9            121.45     B        B5             12
# 12           305.38     C        C1             12
# 14           325.74     B        B2             12

# %%
loan1.home_ownership.value_counts().plot.barh()
plt.title("Distribution of home_ownership")
plt.show()

# %% [markdown]
# #### People who are in mortgage agreement or in Rent are more likely to default than People who have Own Houses with Maximum number of defaults coming from people who live in rented homes.

# %%
loan1.verification_status.value_counts().plot.barh()
plt.title("Distribution of Verification Status")
plt.show()

# %% [markdown]
# #### Not Verified People are more likely to default than verified and Verified ones are more likely to default than ones Whose Source of Income is verified

# %%
loan1.head()
# Out:
#          id  loan_amnt  member_id  term  int_rate  installment home_ownership  \
# 1   1077430       2500    1314167    60     15.27        59.83           RENT
# 8   1071795       5600    1306957    60     21.28       152.39            OWN
# 9   1071570       5375    1306721    60     12.69       121.45           RENT
# 12  1064687       9000    1298717    36     13.49       305.38           RENT
# 14  1069057      10000    1303503    36     10.65       325.74           RENT
#
#     annual_inc verification_status issue_d  loan_status addr_state  \
# 1      30000.0     Source Verified  Dec-11  Charged Off         GA
# 8      40000.0     Source Verified  Dec-11  Charged Off         CA
# 9      15000.0            Verified  Dec-11  Charged Off         TX
# 12     30000.0     Source Verified  Dec-11  Charged Off         VA
# 14    100000.0     Source Verified  Dec-11  Charged Off         CA
#
#     delinq_2yrs  total_rec_late_fee application_type  total_pymnt  \
# 1             0                 0.0       INDIVIDUAL      1008.71
# 8             0                 0.0       INDIVIDUAL       646.02
# 9             0                 0.0       INDIVIDUAL      1476.19
# 12            0                 0.0       INDIVIDUAL      2270.70
# 14            0                 0.0       INDIVIDUAL      7471.99
#
#     last_pymnt_amnt grade sub_grade  issue_d_month
# 1            119.66     C        C4             12
# 8            152.39     F        F2             12
# 9            121.45     B        B5             12
# 12           305.38     C        C1             12
# 14           325.74     B        B2             12

# %%
loan1.grade.value_counts().plot.barh()
plt.title("Distribution of Grade")
plt.show()

# %% [markdown]
# #### Grade assigned as B has the highest default rate than all the other grades

# %%
loan1.application_type.value_counts().plot.barh()
plt.title("Distribution of Grade")
plt.show()

# %% [markdown]
# #### All the loan defaulters are Individual Borrowers

# %%
sns.distplot(loan1.issue_d_month)
plt.title("Distribution of Issue Month")
plt.show()

# %% [markdown]
# #### Maximum Loan Defaults have happened for loans issued in month of Dec

# %%
sns.distplot(loan1.int_rate)
plt.title("Distribution of Interest Rate")
plt.show()

# %%
loan1.head()
# Out:
#          id  loan_amnt  member_id  term  int_rate  installment home_ownership  \
# 1   1077430       2500    1314167    60     15.27        59.83           RENT
# 8   1071795       5600    1306957    60     21.28       152.39            OWN
# 9   1071570       5375    1306721    60     12.69       121.45           RENT
# 12  1064687       9000    1298717    36     13.49       305.38           RENT
# 14  1069057      10000    1303503    36     10.65       325.74           RENT
#
#     annual_inc verification_status issue_d  loan_status addr_state  \
# 1      30000.0     Source Verified  Dec-11  Charged Off         GA
# 8      40000.0     Source Verified  Dec-11  Charged Off         CA
# 9      15000.0            Verified  Dec-11  Charged Off         TX
# 12     30000.0     Source Verified  Dec-11  Charged Off         VA
# 14    100000.0     Source Verified  Dec-11  Charged Off         CA
#
#     delinq_2yrs  total_rec_late_fee application_type  total_pymnt  \
# 1             0                 0.0       INDIVIDUAL      1008.71
# 8             0                 0.0       INDIVIDUAL       646.02
# 9             0                 0.0       INDIVIDUAL      1476.19
# 12            0                 0.0       INDIVIDUAL      2270.70
# 14            0                 0.0       INDIVIDUAL      7471.99
#
#     last_pymnt_amnt grade sub_grade  issue_d_month
# 1            119.66     C        C4             12
# 8            152.39     F        F2             12
# 9            121.45     B        B5             12
# 12           305.38     C        C1             12
# 14           325.74     B        B2             12

# %% [markdown]
# ### Bivariate Analysis on categorical variables

# %% [markdown]
# #### Now considering both the Charged Off and Paid loans and Ignoring Current loan status as it gives us no value

# %%
loan2 = loan[~(loan.loan_status == 'Current')]
loan2.shape
# Out:
# (38577, 20)

# %%
loan2.head()
# Out:
#         id  loan_amnt  member_id  term  int_rate  installment home_ownership  \
# 0  1077501       5000    1296599    36     10.65       162.87           RENT
# 1  1077430       2500    1314167    60     15.27        59.83           RENT
# 2  1077175       2400    1313524    36     15.96        84.33           RENT
# 3  1076863      10000    1277178    36     13.49       339.31           RENT
# 5  1075269       5000    1311441    36      7.90       156.46           RENT
#
#    annual_inc verification_status issue_d  loan_status addr_state  \
# 0     24000.0            Verified  Dec-11   Fully Paid         AZ
# 1     30000.0     Source Verified  Dec-11  Charged Off         GA
# 2     12252.0        Not Verified  Dec-11   Fully Paid         IL
# 3     49200.0     Source Verified  Dec-11   Fully Paid         CA
# 5     36000.0     Source Verified  Dec-11   Fully Paid         AZ
#
#    delinq_2yrs  total_rec_late_fee application_type   total_pymnt  \
# 0            0                0.00       INDIVIDUAL   5863.155187
# 1            0                0.00       INDIVIDUAL   1008.710000
# 2            0                0.00       INDIVIDUAL   3005.666844
# 3            0               16.97       INDIVIDUAL  12231.890000
# 5            0                0.00       INDIVIDUAL   5632.210000
#
#    last_pymnt_amnt grade sub_grade  issue_d_month
# 0           171.62     B        B2             12
# 1           119.66     C        C4             12
# 2           649.91     C        C5             12
# 3           357.48     C        C1             12
# 5           161.03     A        A4             12

# %% [markdown]
# #### Converting Fully Paid to 0 and Charged Off to 1 so that we can carry out analysis easily

# %%
loan2.loan_status = loan2.loan_status.apply(lambda x: 0 if x=='Fully Paid' else 1)

# %%
pv = loan2.pivot_table(values = ['loan_status'], index = ['home_ownership'], columns = ['verification_status'], aggfunc=np.sum)

# %%
pv
# Out:
#                      loan_status
# verification_status Not Verified Source Verified Verified
# home_ownership
# MORTGAGE                   836.0           489.0   1002.0
# NONE                         0.0             NaN      NaN
# OTHER                       10.0             1.0      7.0
# OWN                        187.0           117.0    139.0
# RENT                      1109.0           827.0    903.0

# %% [markdown]
# #### Mortgage-Verified and Rent-Not Verified are the most defaulting categories, Though Mortage Verified is a Peculiar Category.

# %%
pv = loan2.pivot_table(values = ['loan_status'], index = ['home_ownership'], columns = ['grade'], aggfunc=np.sum)

# %%
pv
# Out:
#                loan_status
# grade                    A      B      C      D      E      F     G
# home_ownership
# MORTGAGE             266.0  594.0  541.0  429.0  306.0  149.0  42.0
# NONE                   0.0    0.0    NaN    NaN    NaN    NaN   NaN
# OTHER                  2.0    6.0    2.0    5.0    2.0    1.0   NaN
# OWN                   52.0  115.0  109.0   82.0   51.0   23.0  11.0
# RENT                 282.0  710.0  695.0  602.0  356.0  146.0  48.0

# %% [markdown]
# #### People who are staying in Rented homes and have grades B, C and D are more likely to default. Same applies for people staying in mortgage homes.

# %% [markdown]
# ###  Segmented Univariate Anaylysis

# %%
# Ignoring Current Customers for further Analysis as they give us no meaning full insights.
sns.barplot(data=loan[loan.loan_status!='Current'], x= 'loan_status', y='annual_inc')
plt.show()

# %% [markdown]
# #### From this we see that the people who are Charged Off have less overall annual income.

# %%
sns.barplot(data=loan[loan.loan_status!='Current'], x= 'loan_status', y='int_rate')
plt.show()

# %% [markdown]
# #### The interest rate of Charged Off customers is more than that off Fully paid. Therefore it can be said that high interest rate loans are more likely to default.

# %%
sns.barplot(data=loan[loan.loan_status!='Current'], x= 'loan_status', y='installment')
plt.show()

# %% [markdown]
# #### A similar kind of Analysis as above can be inferred

# %%
sns.barplot(data=loan[loan.loan_status!='Current'], x= 'loan_status', y='total_pymnt')
plt.show()

# %% [markdown]
# #### Default loans receive less amount of money in terms of loan repayments, nearly half than that of fully paid

# %% [markdown]
# ### Bivariate analysis on continous variables

# %%
# Dropping member_id and id columns for plotting a correlation matrix so that it is simple and easy to understand
loan3 = loan1.drop(columns=['id','member_id'])

# %%
loan3.corr()
# Out:
#                     loan_amnt      term  int_rate  installment  annual_inc  \
# loan_amnt            1.000000  0.374624  0.309507     0.918214    0.315718
# term                 0.374624  1.000000  0.447833     0.098396    0.060647
# int_rate             0.309507  0.447833  1.000000     0.281476    0.100461
# installment          0.918214  0.098396  0.281476     1.000000    0.323135
# annual_inc           0.315718  0.060647  0.100461     0.323135    1.000000
# delinq_2yrs         -0.040833 -0.015131  0.119633    -0.020694    0.018523
# total_rec_late_fee   0.054392 -0.050060  0.027247     0.093413    0.047129
# total_pymnt          0.656817  0.255863  0.223431     0.632486    0.244436
# last_pymnt_amnt      0.552708  0.021251  0.153211     0.618982    0.210856
# issue_d_month        0.048815  0.057626  0.067301     0.029544    0.000740
#
#                     delinq_2yrs  total_rec_late_fee  total_pymnt  \
# loan_amnt             -0.040833            0.054392     0.656817
# term                  -0.015131           -0.050060     0.255863
# int_rate               0.119633            0.027247     0.223431
# installment           -0.020694            0.093413     0.632486
# annual_inc             0.018523            0.047129     0.244436
# delinq_2yrs            1.000000            0.031328    -0.017900
# total_rec_late_fee     0.031328            1.000000     0.128799
# total_pymnt           -0.017900            0.128799     1.000000
# last_pymnt_amnt       -0.002434            0.184867     0.355609
# issue_d_month         -0.017620           -0.022816     0.034667
#
#                     last_pymnt_amnt  issue_d_month
# loan_amnt                  0.552708       0.048815
# term                       0.021251       0.057626
# int_rate                   0.153211       0.067301
# installment                0.618982       0.029544
# annual_inc                 0.210856       0.000740
# delinq_2yrs               -0.002434      -0.017620
# total_rec_late_fee         0.184867      -0.022816
# total_pymnt                0.355609       0.034667
# last_pymnt_amnt            1.000000       0.043237
# issue_d_month              0.043237       1.000000

# %%
plt.figure(figsize=(16,9))
sns.heatmap(loan3.corr(), annot = True)
plt.show()

# %% [markdown]
# #### There is a high correlation between installment and loan_amnt, plotting the graph for same we get

# %%
# Bivariate Analysis
sns.scatterplot(loan3.loan_amnt, loan3.installment)
plt.show()

# %% [markdown]
# #### We see that as loan_amnt increases, the monthly installment also increases, and people often tend to take hefty loans and fail to pay their monthly installment and default on loan.

# %% [markdown]
# ### Conclusions

# %% [markdown]
# *  loan is usually borrowed in 5k intervals by more number of people, spikes at 5k intervals say so.
# *  people whose term is 36 months are more likely to default than those who have term as 60 months
# *  People who are in mortgage agreement or in Rent are more likely to default than People who have Own Houses with Maximum number of defaults coming from people who live in Rented homes.
# *  not verified people are more likely to default than verified and verified ones are more likely to default than ones whose source of income is verified
# *  Grades B,C and D account for most number of defualts.
# *  Mortgage-Verified and Rent-Not Verified are the most defaulting categories, though Mortage-Verified is a peculiar category, indicating that it might be possible that verification is not done properly for Mortgage customers.
# *  People who are staying in rented homes and have grades B, C and D are more likely to default. Same applies for people staying in mortgage homes.
# *  The people who are Charged Off have least overall annual income.
# *  The interest rate of Charged Off customers is more than that off Fully paid(ignoring the Current Segment). Therefore it can be said that high interest rate loans are more likely to default. The same trend can be seen for monthly installment as well.
# *  We see that as loan_amnt increases, the monthly installment also increases, and people often tend to take hefty loans and fail to pay their monthly installment and default on loan.

# %% [markdown]
# ### Variables affecting loan default

# %% [markdown]
# 1. term
# 2. home ownership
# 3. verification status
# 4. grades assigned to loan
# 5. annual income
# 6. interest rate
# 7. Combination of home ownership and verification status
